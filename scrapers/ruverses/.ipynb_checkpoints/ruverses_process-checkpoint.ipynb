# %%
import json
import pandas as pd
import re

# %%
file = open("./data/texts_ruverses.json", "r")
j = json.load(file)
lst = []
for i in j:
    lst.append([i["article"], i["original"], i["text"], i["url"]])

# %%
df = pd.DataFrame(lst, columns=["article","original","text", "url"])
df = df[df.text.str.contains("английский")].reset_index(drop=True)

# %%
df.original = df.original.apply(lambda x: re.sub("\n+", "\n", x).strip())
df.article = df.article.apply(lambda x: re.sub("\n+", "\n", x).strip())

# %%
df["diff"] = df.article.str.split("\n").str.len() - df.original.str.split("\n").str.len()
problem = df[abs(df.article.str.split("\n").str.len() - df.original.str.split("\n").str.len()) != 0]

# %%
len(df)
# Out:
# 4344

# %%
problem.head()
# Out:
#                                               article  \
# 0   I'm fond of the old speech.\nThere's a charm i...
# 2   Fifteen boys and maybe more,\nor feuer than fi...
# 5   Along my street for so many years \nI hear ste...
# 7   (fragment)\nOver my street for many-many years...
# 14  I love, Marina, that you were, like all, \ntha...
#
#                                              original  \
# 0   Влечет меня старинный слог.\nЕсть обаянье в др...
# 2   Пятнадцать мальчиков, а может быть и больше,\n...
# 5   По улице моей который год\nзвучат шаги — мои д...
# 7   По улице моей который год\nзвучат шаги — мои д...
# 14  Люблю, Марина, что тебя, как всех,\nчто, — как...
#
#                                                  text  \
# 0   Перевод стихотворения Беллы Ахмадулиной «Влече...
# 2   Перевод стихотворения Беллы Ахмадулиной «Пятна...
# 5   Перевод стихотворения Беллы Ахмадулиной «По ул...
# 7   Перевод стихотворения Беллы Ахмадулиной «По ул...
# 14  Перевод стихотворения Беллы Ахмадулиной «Уроки...
#
#                                                   url  diff
# 0   https://ruverses.com/bella-akhmadulina/i-m-fon...    -1
# 2   https://ruverses.com/bella-akhmadulina/fifteen...    -2
# 5   https://ruverses.com/bella-akhmadulina/along-m...   -12
# 7   https://ruverses.com/bella-akhmadulina/along-m...    -6
# 14  https://ruverses.com/bella-akhmadulina/music-l...    -1

# %%
# sep = "\n\n\n#new_poem#\n"
# translation_sep = "\n#translation#\n"
# url_sep = "\n#url#\n"
# diff_sep = "\n#diff#\n"

# with open("ruverses_lookup.txt", "w") as file:
#     for idx, (en, ru, _, url, diff) in problem.iterrows():
#         ru = re.sub("\n+", "\n", ru)
#         ru = re.sub("\n+$", "", ru)
#         ru = re.sub("^\n+", "", ru)
#         en = re.sub("\n+", "\n", en)
#         en = re.sub("\n+$", "", en)
#         en = re.sub("^\n+", "", en)
        
#         file.write(sep)
#         file.write(str(diff))
#         file.write(diff_sep)
#         file.write(ru)
#         file.write(translation_sep)
#         file.write(en)
#         file.write(url_sep)
#         file.write(url)

# %%
sep = "\n\n\n#new_poem#\n"
translation_sep = "\n#translation#\n"
url_sep = "\n#url#\n"
diff_sep = "\n#diff#\n"

# %%
lst = []
with open("tania_lookup.txt", "r") as file:
    text = file.read()
    for pack in list(filter(None, text.split(sep))):
        diff = pack.split(diff_sep)[0]
        other = pack.split(diff_sep)[1]
        url = other.split(url_sep)[1]
        en, ru = other.split(url_sep)[0].split(translation_sep)
        lst.append([en, ru, url])

# %%
lst = []
with open("ruverses_lookup_reserved.txt", "r") as file:
    text = file.read()
    for pack in list(filter(None, text.split(sep))):
        diff = pack.split(diff_sep)[0]
        other = pack.split(diff_sep)[1]
        url = other.split(url_sep)[1]
        en, ru = other.split(url_sep)[0].split(translation_sep)
        lst.append([en, ru, url])

# %%
add = pd.DataFrame(lst, columns=["en", "ru", "url"])

# %%
add.head()
# Out:
#                                                     en  \
# 0    Влечет меня старинный слог.\nЕсть обаянье в др...
# 1    Пятнадцать мальчиков, а может быть и больше,\n...
# 2    По улице моей который год\nзвучат шаги — мои д...
# 3    По улице моей который год\nзвучат шаги — мои д...
# 4    Люблю, Марина, что тебя, как всех,\nчто, — как...
# ..                                                 ...
# 820  2\nПоколенью с сиренью\nИ с Пасхой в Кремле,\n...
# 821  Ползёт подземный змей,\nПолзёт, везёт людей.\n...
# 822  7\nВ мыслях об ином, инаком,\nИ ненайденном, к...
# 823  О слёзы на глазах!\nПлач гнева и любви!\nО Чех...
# 824  Всё повторяю первый стих\nИ всё переправляю сл...
#
#                                                     ru  \
# 0    I'm fond of the old speech.\nThere's a charm i...
# 1    Fifteen boys and maybe more,\nor feuer than fi...
# 2    Along my street for so many years \nI hear ste...
# 3    Over my street for many-many years,\nsound the...
# 4    I love, Marina, that you were, like all, \ntha...
# ..                                                 ...
# 820  2\nGeneration with lilac\nAnd on Easter in Kre...
# 821  The underground snake crawls,\nCrawls, carries...
# 822  Thinking of something, carelessly,\nSomething ...
# 823  Oh, tears in my eyes!\nLove, anger, all in vai...
# 824  All repeat the first line\nAnd all the well-wo...
#
#                                                    url
# 0    https://ruverses.com/bella-akhmadulina/i-m-fon...
# 1    https://ruverses.com/bella-akhmadulina/fifteen...
# 2    https://ruverses.com/bella-akhmadulina/along-m...
# 3    https://ruverses.com/bella-akhmadulina/along-m...
# 4    https://ruverses.com/bella-akhmadulina/music-l...
# ..                                                 ...
# 820  https://ruverses.com/marina-tsvetaeva/to-fathe...
# 821  https://ruverses.com/marina-tsvetaeva/readers-...
# 822  https://ruverses.com/marina-tsvetaeva/thinking...
# 823  https://ruverses.com/marina-tsvetaeva/oh-tears...
# 824  https://ruverses.com/marina-tsvetaeva/all-repe...
#
# [825 rows x 3 columns]

# %%
prefin = df[abs(df.article.str.split("\n").str.len() - df.original.str.split("\n").str.len()) == 0].copy()

# %%
prefin = prefin[["article", "original", "url"]]

# %%
prefin.columns = add.columns

# %%
fin = prefin.append(add).reset_index(drop=True)

# %%
fin = fin[fin.en.str.len() > 5]
fin = fin[fin.ru.str.len() > 5]
fin = fin.reset_index(drop=True)

# %%
fin
# Out:
#                                                      en  \
# 0     There is a freedom blissful in a twilight\nFro...
# 1     Laughing, delighting, and rebelling\nIn all he...
# 2     Winter, to me your gestures are\ncold and care...
# 3     Along my street, these steady steps resound  \...
# 4     Here're the girls — they wish to love,\nHere'r...
# ...                                                 ...
# 4314  2\nПоколенью с сиренью\nИ с Пасхой в Кремле,\n...
# 4315  Ползёт подземный змей,\nПолзёт, везёт людей.\n...
# 4316  7\nВ мыслях об ином, инаком,\nИ ненайденном, к...
# 4317  О слёзы на глазах!\nПлач гнева и любви!\nО Чех...
# 4318  Всё повторяю первый стих\nИ всё переправляю сл...
#
#                                                      ru  \
# 0     Есть в сумерках блаженная свобода \nот явных ч...
# 1     Смеясь, ликуя и бунтуя, \nв своей безвыходной ...
# 2     О жест зимы ко мне, \nхолодный и прилежный. \n...
# 3     По улице моей который год\nзвучат шаги — мои д...
# 4     Вот девочки — им хочется любви.\nВот мальчики ...
# ...                                                 ...
# 4314  2\nGeneration with lilac\nAnd on Easter in Kre...
# 4315  The underground snake crawls,\nCrawls, carries...
# 4316  Thinking of something, carelessly,\nSomething ...
# 4317  Oh, tears in my eyes!\nLove, anger, all in vai...
# 4318  All repeat the first line\nAnd all the well-wo...
#
#                                                     url
# 0     https://ruverses.com/bella-akhmadulina/twiligh...
# 1     https://ruverses.com/bella-akhmadulina/laughin...
# 2        https://ruverses.com/bella-akhmadulina/winter/
# 3     https://ruverses.com/bella-akhmadulina/along-m...
# 4     https://ruverses.com/bella-akhmadulina/april/2...
# ...                                                 ...
# 4314  https://ruverses.com/marina-tsvetaeva/to-fathe...
# 4315  https://ruverses.com/marina-tsvetaeva/readers-...
# 4316  https://ruverses.com/marina-tsvetaeva/thinking...
# 4317  https://ruverses.com/marina-tsvetaeva/oh-tears...
# 4318  https://ruverses.com/marina-tsvetaeva/all-repe...
#
# [4319 rows x 3 columns]

# %%
fin.to_csv("./data/ruverses_fin.csv", index=False)
